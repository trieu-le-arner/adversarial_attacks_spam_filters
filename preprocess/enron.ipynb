# %%
from google.colab import drive
drive.mount('/content/drive')

root_path = '/content/drive/MyDrive/learning/nus/cs5260/project'
data_path = root_path + '/data'
cleaned_data_path = root_path + '/data/cleaned'
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
emails = pd.read_csv(data_path + '/enron.csv')

# Rename the column Spam/Ham to spam
emails.rename(columns={'Spam/Ham': 'spam'}, inplace=True)

# Update ham to 0 and spam = 1 in spam column
emails['spam'] = emails['spam'].map({'ham': 0, 'spam': 1})

# Fill empty string for empty / NA value in Subject and Message columns
emails['Subject'].fillna('', inplace=True)
emails['Message'].fillna('', inplace=True)

# Create a new column called text by concatenating Subject and Message
emails['text'] = emails['Subject'] + ' ' + emails['Message']
emails['original_text'] = emails['text']
emails.drop(columns=['Subject', 'Message', 'Message ID', 'Date'], inplace=True)

# Count by spam status
emails['spam'].value_counts()
# Out:
# spam
# 1    17171
# 0    16545
# Name: count, dtype: int64

# %%
print('Before removing duplicate emails:', emails.shape)

emails.drop_duplicates(inplace=True)
print('After removing duplicate emails:', emails.shape)

# %%
# Spam emails
emails[emails['spam'] == 1].sample(10)
# Out:
#        spam                                               text  \
# 30342     1  i am so happy " do i have to dress for the nex...
# 3713      1                 learn to make a fortune on ebay !
# 29690     1  get a free wireless ready toshiba laptop ! con...
# 29524     1  how to make 400 dollars a day from home . pop ...
# 22141     1  solid loans for the usa ! dear sir or madam ,\...
# 20844     1  offce x * p professional $ 60 minnesota , whic...
# 19057     1  stoop it deaaaaad in it ' s tracks hi saundra ...
# 22324     1  get laid tonight there is this free date site ...
# 30365     1  congratulations bank giro loterij\ninternation...
# 3801      1  be a men byronizes munched ! armpit , budweise...
#
#                                            original_text
# 30342  i am so happy " do i have to dress for the nex...
# 3713                  learn to make a fortune on ebay !
# 29690  get a free wireless ready toshiba laptop ! con...
# 29524  how to make 400 dollars a day from home . pop ...
# 22141  solid loans for the usa ! dear sir or madam ,\...
# 20844  offce x * p professional $ 60 minnesota , whic...
# 19057  stoop it deaaaaad in it ' s tracks hi saundra ...
# 22324  get laid tonight there is this free date site ...
# 30365  congratulations bank giro loterij\ninternation...
# 3801   be a men byronizes munched ! armpit , budweise...

# %%
# Non-spam emails
emails[emails['spam'] == 0].sample(10)
# Out:
#        spam                                               text  \
# 662       0  aspect resources - meter # 78033 , # 78032 - 3...
# 12681     0  ena trading track update any changes to the at...
# 23442     0  enron technology showcase announcement that ' ...
# 16933     0  pdci / iso share ( nob ) south to north derate...
# 14461     0  re : integration meeting i have arranged for t...
# 12009     0  fw : enron canada update - 06 / 25 / 01 fyi\n-...
# 23524     0  request submitted : access request for kenneth...
# 6650      0  re : reminder thanks , so much for your support !
# 14236     0  re : enron online counterparties mark\ni will ...
# 3507      0  2001 special stock option grant awards we are ...
#
#                                            original_text
# 662    aspect resources - meter # 78033 , # 78032 - 3...
# 12681  ena trading track update any changes to the at...
# 23442  enron technology showcase announcement that ' ...
# 16933  pdci / iso share ( nob ) south to north derate...
# 14461  re : integration meeting i have arranged for t...
# 12009  fw : enron canada update - 06 / 25 / 01 fyi\n-...
# 23524  request submitted : access request for kenneth...
# 6650   re : reminder thanks , so much for your support !
# 14236  re : enron online counterparties mark\ni will ...
# 3507   2001 special stock option grant awards we are ...

# %%
import ast

def parse_and_concatenate(value):
    try:
        # Attempt to parse the string as a list
        parsed_value = ast.literal_eval(value)
        if isinstance(parsed_value, list):
            # Join the list elements into a single string if parsing is successful
            return ' '.join(str(item) for item in parsed_value)
    except (ValueError, SyntaxError):
        # Return the original value if parsing fails or if it's not a list
        return value

    # Return the original value if it's not a list
    return value

# Apply the function to the DataFrame column
emails['text'] = emails['text'].apply(parse_and_concatenate)

# %%
from bs4 import BeautifulSoup

def extract_text(html):
    soup = BeautifulSoup(html, "lxml")
    return soup.get_text()

emails['text'] = emails['text'].apply(extract_text)
# Out:
# <ipython-input-7-5df6bfd0c925>:4: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   soup = BeautifulSoup(html, "lxml")

# %%
emails['text'] = emails['text'].apply(lambda x: x.replace("\\n", " ").replace("\\r", " ").replace("\\t", " "))
emails['text'] = emails['text'].str.replace(r'\s+', ' ', regex=True).str.replace(
    '[^a-zA-Z0-9 \!\?\.,;\:\-\—\(\)\[\]\{\}\'\"%\$&\*\/=@#\\+]',
    '',
    regex=True
)

emails
# Out:
#        spam                                               text  \
# 0         0                      christmas tree farm pictures
# 1         0  vastar resources , inc . gary , production fro...
# 2         0  calpine daily gas nomination - calpine daily g...
# 3         0  re : issue fyi - see note below - already done...
# 4         0  meter 7268 nov allocation fyi . - - - - - - - ...
# ...     ...                                                ...
# 33709     1  cure premature ejaculation hello , did you eja...
# 33711     1  = ? iso - 8859 - 1 ? q ? good  news  c = edali...
# 33712     1  all prescript medicines are on special . to be...
# 33713     1  the next generation online pharmacy . are you ...
# 33714     1  bloow in 5 - 10 times the time learn how to la...
#
#                                            original_text
# 0                          christmas tree farm pictures
# 1      vastar resources , inc . gary , production fro...
# 2      calpine daily gas nomination - calpine daily g...
# 3      re : issue fyi - see note below - already done...
# 4      meter 7268 nov allocation fyi .\n- - - - - - -...
# ...                                                  ...
# 33709  cure premature ejaculation hello ,\ndid you ej...
# 33711  = ? iso - 8859 - 1 ? q ? good _ news _ c = eda...
# 33712  all prescript medicines are on special . to be...
# 33713  the next generation online pharmacy . are you ...
# 33714  bloow in 5 - 10 times the time learn how to la...
#
# [30494 rows x 3 columns]

# %%
emails['original_text'] = emails['text']

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# %%
def tokenize(text):
    return ' '.join(tokenizer.tokenize(text))

emails['text'] = emails['text'].apply(tokenize)

# Print the updated DataFrame
emails.head()
# Out:
#    spam                                               text  \
# 0     0                       christmas tree farm pictures
# 1     0  vast ##ar resources , inc . gary , production ...
# 2     0  cal ##pine daily gas nomination - cal ##pine d...
# 3     0  re : issue f ##yi - see note below - already d...
# 4     0  meter 72 ##6 ##8 nov allocation f ##yi . - - -...
#
#                                        original_text
# 0                      christmas tree farm pictures
# 1  vastar resources , inc . gary , production fro...
# 2  calpine daily gas nomination - calpine daily g...
# 3  re : issue fyi - see note below - already done...
# 4  meter 7268 nov allocation fyi .\n- - - - - - -...

# %%
print(emails.shape)

# Strip whitespace from the text column
emails['text'] = emails['text'].str.strip()

# Remove emails with empty text
emails = emails[emails['text'].str.len() > 50]

print(emails.shape)
# Out:
# (30494, 3)
# (30067, 3)

# %%
emails['spam'].value_counts()
# Out:
# spam
# 0    15788
# 1    14279
# Name: count, dtype: int64

# %%
# Spam emails
emails[emails['spam'] == 1].sample(10)
# Out:
#        spam                                               text  \
# 30946     1  . via ##g ' ra 80 % discount ' new cl ##all ##...
# 31340     1  it is your way to get quick relief it is a sma...
# 18610     1  this is super ! h real time , online , instant...
# 22144     1  michael romero tu ##e , 21 jun 2005 07 : 33 : ...
# 25072     1  herald community herald - article on pc ' s mi...
# 26915     1  our cool ##l med ##z how to save on your med #...
# 21175     1  spec ##al offer for w ##ndo ##ws 20 o ##o adva...
# 19099     1  gr ##ox ##w your penis our pg ##f - q 3 pe ##c...
# 15684     1  con ##fi ##dant . department of minerals and e...
# 4785      1  all of these lonely people would like someone ...
#
#                                            original_text
# 30946  . viag ' ra 80 % discount ' new clalls softtab...
# 31340  it is your way to get quick relief it is a sma...
# 18610  this is super ! h real time ,\nonline , instan...
# 22144  michael romero tue , 21 jun 2005 07 : 33 : 23 ...
# 25072  herald community herald - article on pc ' s mi...
# 26915  our cooll medz how to save on your medlcations...
# 21175  specal offer for wndows 20 oo advanced server ...
# 19099   groxw\nyour\npenis\nour pgf - q 3 pecunis enl...
# 15684  confidant . department of minerals and energy\...
# 4785   all of these lonely people would like someone ...

# %%
# Non-spam emails
emails[emails['spam'] == 0].sample(10)
# Out:
#        spam                                               text  \
# 903       0  wc 53 ##3 revision and notice of force maj ##e...
# 2406      0  en ##ron / hp ##l actual ##s for january 15 , ...
# 3521      0  re : tx ##u may 01 this deal was not transport...
# 17689     0  start date : 1 / 12 / 02 ; hour ##ah ##ead hou...
# 3002      0  re : no ##m / actual flow for april 4 th we ag...
# 11586     0  forthcoming un ##fa ##vor ##able new york time...
# 580       0  re : 98 - 68 ##9 ##2 for 3 / 15 / 2000 and 3 /...
# 6171      0  here ' s your chance what do we need to know t...
# 2182      0  en ##ron / hp ##l actual ##s for december 6 , ...
# 23595     0  request submitted : access request for kelly ....
#
#                                            original_text
# 903    wc 533 revision and notice of force majeure ( ...
# 2406   enron / hpl actuals for january 15 , 2001 janu...
# 3521   re : txu may 01 this deal was not transported ...
# 17689  start date : 1 / 12 / 02 ; hourahead hour : 16...
# 3002   re : nom / actual flow for april 4 th we agree...
# 11586  forthcoming unfavorable new york times article...
# 580    re : 98 - 6892 for 3 / 15 / 2000 and 3 / 23 / ...
# 6171   here ' s your chance what do we need to know t...
# 2182   enron / hpl actuals for december 6 , 2000 teco...
# 23595  request submitted : access request for kelly ....

# %%
# prompt: Select out emails with email addresses

import re

def extract_emails(text):
  """
  This function extracts email addresses from a given text.
  """
  email_regex = r"[a-z0-9._%+-]+@[a-z0-9.-]+\.[a-z]{2,}"
  return re.findall(email_regex, text)

emails['emails'] = emails['text'].apply(extract_emails)

# Print the DataFrame with extracted email addresses
print(emails[emails['emails'].str.len() > 0].shape)

# Drop emails column
emails.drop(columns=['emails'], inplace=True)
# Out:
# (0, 4)
# <ipython-input-12-3b45509cea98>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails['emails'] = emails['text'].apply(extract_emails)
# <ipython-input-12-3b45509cea98>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails.drop(columns=['emails'], inplace=True)

# %%
# prompt: Find rows contains email forwarding information

emails[emails['text'].str.contains(r'forward')]
# Out:
#        spam                                               text  \
# 1         0  vastar resources , inc . gary , production fro...
# 3         0  re : issue fyi - see note below - already done...
# 4         0  meter 7268 nov allocation fyi . - - - - - - - ...
# 7         0  duns number changes fyi - - - - - - - - - - - ...
# 11        0  lst rev dec . 1999 josey ranch nom fyi - - - -...
# ...     ...                                                ...
# 33589     1  is it a microcap miracle ? investor alert - im...
# 33629     1  wall - street pulse * * * watch this one july ...
# 33655     1  notification adexec investerings firma max - h...
# 33691     1  quicker effects . lesser costs . best bargain ...
# 33706     1  = ? iso - 8859 - 2 ? q ? my  proposition ? = f...
#
#                                            original_text
# 1      vastar resources , inc . gary , production fro...
# 3      re : issue fyi - see note below - already done...
# 4      meter 7268 nov allocation fyi . - - - - - - - ...
# 7      duns number changes fyi - - - - - - - - - - - ...
# 11     lst rev dec . 1999 josey ranch nom fyi - - - -...
# ...                                                  ...
# 33589  is it a microcap miracle ? investor alert - im...
# 33629  wall - street pulse * * * watch this one july ...
# 33655  notification adexec investerings firma max - h...
# 33691  quicker effects . lesser costs . best bargain ...
# 33706  = ? iso - 8859 - 2 ? q ? my  proposition ? = f...
#
# [5345 rows x 3 columns]

# %%
# Find duplicate emails
duplicate_emails = emails[emails.duplicated(subset='text', keep=False)]
duplicate_emails.sort_values(by='text')
# Out:
#        spam                                               text  \
# 2828      0  04 / 01 assignment , termination , expiration ...
# 2831      0  04 / 01 assignment , termination , expiration ...
# 9456      0  2 - survey / information email 5 - 7 - 01 curr...
# 9458      0  2 - survey / information email 5 - 7 - 01 curr...
# 9455      0  3 - urgent - to prevent loss of information cr...
# ...     ...                                                ...
# 8920      0  yen outlook vince , as a followup to our meeti...
# 9428      0  your advice is appreciated vince , in the morn...
# 9423      0  your advice is appreciated vince , in the morn...
# 23973     0  your help needed please - cross - commodity re...
# 23974     0  your help needed please - cross - commodity re...
#
#                                            original_text
# 2828   04 / 01 assignment , termination , expiration ...
# 2831   04 / 01 assignment , termination , expiration ...
# 9456   2 - survey / information email 5 - 7 - 01 curr...
# 9458   2 - survey / information email 5 - 7 - 01 curr...
# 9455   3 - urgent - to prevent loss of information cr...
# ...                                                  ...
# 8920   yen outlook vince , as a followup to our meeti...
# 9428   your advice is appreciated vince , in the morn...
# 9423   your advice is appreciated vince , in the morn...
# 23973  your help needed please - cross - commodity re...
# 23974  your help needed please - cross - commodity re...
#
# [711 rows x 3 columns]

# %%
# Drop duplidate emails
emails.drop_duplicates(subset=['text', 'spam'], inplace=True)
emails.shape
# Out:
# <ipython-input-15-fcea7ded5ee9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails.drop_duplicates(subset=['text', 'spam'], inplace=True)
# (29711, 3)

# %%
emails['spam'].value_counts()
# Out:
# spam
# 0    15468
# 1    14243
# Name: count, dtype: int64

# %%
# Spam emails
emails[emails['spam'] == 1].sample(10)
# Out:
#        spam                                               text  \
# 31529     1  p % ill to improve cu & m flavour and v ! olum...
# 4526      1  we have vicodin and anything else save over 50...
# 4132      1  the only fix to penis growth limited time offe...
# 20823     1  over 150 fda approved meds % rnd  alt % rnd  a...
# 15495     1  discounted microsoft money 2004 standard get s...
# 33193     1  it ' s not a joke on our thousand , side happy...
# 30936     1  warez cd ' s microsoft windows xp professional...
# 19305     1  $ 54873 hello , i sent you an email a few days...
# 9957      1  take positi 0 ns before breaking news expiosio...
# 29898     1  inexpensive online medication here handout all...
#
#                                            original_text
# 31529  p % ill to improve cu & m flavour and v ! olum...
# 4526   we have vicodin and anything else save over 50...
# 4132   the only fix to penis growth limited time offe...
# 20823  over 150 fda approved meds % rnd  alt % rnd  a...
# 15495  discounted microsoft money 2004 standard get s...
# 33193  it ' s not a joke on our thousand , side happy...
# 30936  warez cd ' s microsoft windows xp professional...
# 19305  $ 54873 hello , i sent you an email a few days...
# 9957   take positi 0 ns before breaking news expiosio...
# 29898  inexpensive online medication here handout all...

# %%
# # prompt: Compute document embedding of all emails; then find all emails very similar to each other

# # Import necessary libraries
# from sklearn.feature_extraction.text import TfidfVectorizer
# from sklearn.metrics.pairwise import cosine_similarity

# # Initialize a TfidfVectorizer object
# vectorizer = TfidfVectorizer()

# # Fit the vectorizer on the text column of the emails DataFrame
# X = vectorizer.fit_transform(emails['text'])

# # Compute the cosine similarity between each pair of emails
# cosine_matrix = cosine_similarity(X, X)

# # Find the indices of the most similar emails for each email
# most_similar_indices = cosine_matrix.argsort()[:, -5:-1]

# # Print the most similar emails for the first 10 emails
# for i in range(10):
#     print(f"Most similar emails for email {i + 1}:")
#     for j in most_similar_indices[i]:
#         print(f" - Email {j + 1}: {emails['text'].iloc[j]}")

# %%
# How many unique words are there across all text values?
unique_words = set()
for text in emails['text']:
    unique_words.update(text.split())
print(len(unique_words))
# Out:
# 158272

# %%
emails[emails['text'].str.contains(r'html')]
# Out:
#        spam                                               text  \
# 304       0  http : / / www . pge - texas . com / www / gtt...
# 959       0  june specials ! ! * * summer specials * * valu...
# 1224      0  kingwood cove - $ 10 before 10 am ! only $ 10 ...
# 1295      0  fw : please read . . don ' t delete - - - - - ...
# 1315      0  kingwood cove - 2 play " for " $ 20 thanks for...
# ...     ...                                                ...
# 33485     1  web design & development hello , as a professi...
# 33526     1  compare p ) rescription drug prices find all y...
# 33530     1  urgent message dearest one , i am madam . adel...
# 33566     1  need more energy , more money ? free sample ! ...
# 33588     1  mexico business directory available linux - ke...
#
#                                            original_text
# 304    http : / / www . pge - texas . com / www / gtt...
# 959    june specials ! ! * * summer specials * * valu...
# 1224   kingwood cove - $ 10 before 10 am ! only $ 10 ...
# 1295   fw : please read . . don ' t delete - - - - - ...
# 1315   kingwood cove - 2 play " for " $ 20 thanks for...
# ...                                                  ...
# 33485  web design & development hello , as a professi...
# 33526  compare p ) rescription drug prices find all y...
# 33530  urgent message dearest one , i am madam . adel...
# 33566  need more energy , more money ? free sample ! ...
# 33588  mexico business directory available linux - ke...
#
# [1006 rows x 3 columns]

# %%
import pandas as pd
import nltk
from nltk.corpus import words
from nltk.tokenize import word_tokenize
import re

# Ensure you have the necessary NLTK datasets downloaded
nltk.download('words')
nltk.download('punkt')
nltk.download('wordnet')

english_words = set(words.words())
lemmatizer = nltk.WordNetLemmatizer()

def count_non_english_words(text):
    # Tokenize the text into words
    text = re.sub(r'[^a-zA-Z0-9 ]', '', text)
    tokens = word_tokenize(text)
    # Lematize tokens using lematizer
    tokens = [lemmatizer.lemmatize(word.lower()) for word in tokens]
    # Count total words and non-English words
    total_words = len(tokens)
    non_english_words = sum(1 for word in tokens if word not in english_words)

    # Return the count of non-English words and total words
    return non_english_words, total_words

# Apply the function to the 'text' column and calculate the percentage of non-English words
emails['non_english_info'] = emails['original_text'].apply(count_non_english_words)
emails['percentage_non_english'] = emails['non_english_info'].apply(lambda x: x[0] / x[1] if x[1] > 0 else 0)

# Filter emails containing more than 30% non-English words
filtered_emails = emails[emails['percentage_non_english'] > 0.60].sort_values(by='percentage_non_english', ascending=False)

filtered_emails.shape
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# <ipython-input-20-2cce9f71d457>:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails['non_english_info'] = emails['original_text'].apply(count_non_english_words)
# <ipython-input-20-2cce9f71d457>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   emails['percentage_non_english'] = emails['non_english_info'].apply(lambda x: x[0] / x[1] if x[1] > 0 else 0)
# (1422, 5)

# %%
# Remove filtered_emails from email dataframe
print(emails.shape)
emails = emails[~emails.index.isin(filtered_emails.index)]
print(emails.shape)
# Out:
# (29711, 5)
# (28289, 5)

# %%
# Count unique words in text column
unique_words = set()
for text in emails['text']:
    unique_words.update(text.split())

print(len(unique_words))
# Out:
# 128424

# %%
emails['spam'].value_counts()
# Out:
# spam
# 0    14577
# 1    13712
# Name: count, dtype: int64

# %%
# Store into the cleaned folder
emails[['text', 'original_text', 'spam']].to_csv(cleaned_data_path + '/enron.csv', index=False)
